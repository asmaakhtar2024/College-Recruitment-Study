# %% [markdown]
# # Project 1
# ## Asma Akhtar
# ### I will be working on NON Majors Survey Result from 2023.

# %%
#import packages 
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Read Dataset

# %%
#Read in the data files 
datafile="fall2023non-majors.csv"
df=pd.read_csv(datafile,index_col=0)
#Display data
df
# Out:
#                              Which course are you currently enrolled in?  \
# Timestamp
# 2023/09/05 9:36:31 PM EST          CMP 101 Computer Information Literacy
# 2023/09/05 9:42:31 PM EST          CMP 101 Computer Information Literacy
# 2023/09/05 10:00:08 PM EST         CMP 101 Computer Information Literacy
# 2023/09/05 11:12:17 PM EST  CMP 126 Computer Technology and Applications
# 2023/09/05 11:56:29 PM EST  CMP 126 Computer Technology and Applications
# ...                                                                  ...
# 2023/09/19 6:04:34 PM EST    CMP 135 Computer Concepts with Applications
# 2023/09/19 6:05:55 PM EST          CMP 101 Computer Information Literacy
# 2023/09/19 6:07:54 PM EST    CMP 135 Computer Concepts with Applications
# 2023/09/19 6:08:11 PM EST    CMP 135 Computer Concepts with Applications
# 2023/09/19 10:44:14 PM EST   CMP 135 Computer Concepts with Applications
#
# ...

# %% [markdown]
# # Describing Categorical Data

# %%
#Describes the numeric columns
df.describe()
# Out:
#        On a scale of 1 to 5, with 1 being not at all interested and 5 being extremely interested, how interested are you taking more courses in Computer Science, Information Technology or Game Development?
# count                                         105.000000
# mean                                            2.495238
# std                                             1.136152
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             3.000000
# 75%                                             3.000000
# max                                             5.000000

# %% [markdown]
# # Displaying the column names from the dataset

# %%
#Columns names in the dataset
df.columns
# Out:
# Index(['Which course are you currently enrolled in?',
#        'How did you hear about County College of Morris? [CCM Web site]',
#        'How did you hear about County College of Morris? [Social Media]',
#        'How did you hear about County College of Morris? [Community Event]',
#        'How did you hear about County College of Morris? [Family member or friend]',
#        'How did you hear about County College of Morris? [Current CCM student]',
#        'How did you hear about County College of Morris? [CCM Alumni]',
#        'How did you hear about County College of Morris? [High School Teacher]',
#        'How did you hear about County College of Morris? [High School Counselor]',
#        'How did you hear about County College of Morris? [In-app advertisement]',
#        'How did you hear about County College of Morris? [Employer]',
#        'How did you hear about County College of Morris? [Billboard]',
# ...

# %% [markdown]
# # Number of rows and columns of the dataset

# %%
#Displaying the number of rows and columns in the dataset
df.shape
# Out:
# (105, 95)

# %% [markdown]
# # datatype of the dataset (object, integer,...)

# %%
#data type of each column 
df.dtypes
# Out:
# Which course are you currently enrolled in?                                                                                                  object
# How did you hear about County College of Morris? [CCM Web site]                                                                              object
# How did you hear about County College of Morris? [Social Media]                                                                              object
# How did you hear about County College of Morris? [Community Event]                                                                           object
# How did you hear about County College of Morris? [Family member or friend]                                                                   object
#                                                                                                                                               ...
# ...

# %% [markdown]
# # Displaying the first 5 rows of the dataset

# %%
#First 5 rows of the dataset
df.head()
# Out:
#                              Which course are you currently enrolled in?  \
# Timestamp
# 2023/09/05 9:36:31 PM EST          CMP 101 Computer Information Literacy
# 2023/09/05 9:42:31 PM EST          CMP 101 Computer Information Literacy
# 2023/09/05 10:00:08 PM EST         CMP 101 Computer Information Literacy
# 2023/09/05 11:12:17 PM EST  CMP 126 Computer Technology and Applications
# 2023/09/05 11:56:29 PM EST  CMP 126 Computer Technology and Applications
#
#                            How did you hear about County College of Morris? [CCM Web site]  \
# Timestamp
# 2023/09/05 9:36:31 PM EST                                                 Yes
# 2023/09/05 9:42:31 PM EST                                                  No
# 2023/09/05 10:00:08 PM EST                                                 No
# 2023/09/05 11:12:17 PM EST                                                Yes
# 2023/09/05 11:56:29 PM EST                                                 No
#
# ...

# %% [markdown]
# # Displaying the last 5 rows of the dataset

# %%
#Last 5 rows of the dataset
df.tail()
# Out:
#                             Which course are you currently enrolled in?  \
# Timestamp
# 2023/09/19 6:04:34 PM EST   CMP 135 Computer Concepts with Applications
# 2023/09/19 6:05:55 PM EST         CMP 101 Computer Information Literacy
# 2023/09/19 6:07:54 PM EST   CMP 135 Computer Concepts with Applications
# 2023/09/19 6:08:11 PM EST   CMP 135 Computer Concepts with Applications
# 2023/09/19 10:44:14 PM EST  CMP 135 Computer Concepts with Applications
#
#                            How did you hear about County College of Morris? [CCM Web site]  \
# Timestamp
# 2023/09/19 6:04:34 PM EST                                                  No
# 2023/09/19 6:05:55 PM EST                                                 Yes
# 2023/09/19 6:07:54 PM EST                                                 Yes
# 2023/09/19 6:08:11 PM EST                                                 Yes
# 2023/09/19 10:44:14 PM EST                                       Don't recall
#
# ...

# %% [markdown]
# # Displaying random 5 rows from the dataset

# %%
#Random sample of the dataset
df.sample()
# Out:
#                              Which course are you currently enrolled in?  \
# Timestamp
# 2023/09/06 11:02:09 AM EST  CMP 126 Computer Technology and Applications
#
#                            How did you hear about County College of Morris? [CCM Web site]  \
# Timestamp
# 2023/09/06 11:02:09 AM EST                                                 No
#
#                            How did you hear about County College of Morris? [Social Media]  \
# Timestamp
# 2023/09/06 11:02:09 AM EST                                                 No
#
#                            How did you hear about County College of Morris? [Community Event]  \
# Timestamp
# 2023/09/06 11:02:09 AM EST                                                 No
#
#                            How did you hear about County College of Morris? [Family member or friend]  \
# Timestamp
# 2023/09/06 11:02:09 AM EST                                                Yes
#
# ...

# %% [markdown]
# # Details of the dataset

# %%
#Number of columns, names, non-null values, datatype for each column 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 105 entries, 2023/09/05 9:36:31 PM EST to 2023/09/19 10:44:14 PM EST
# Data columns (total 95 columns):
#  #   Column                                                                                                                                                                                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                                           --------------  -----
# ...

# %% [markdown]
# # Now that we have explored the dataset now we will clean the data set

# %%
#drop columns that aren't relevant to our analysis
df.drop(axis=1, columns=['Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Open House]',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Instant Decision Day]',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [On-Campus Information Session]',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Titans Tuesday (Virtual) Information Session]',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Women Who Dare]',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Regional College Fair]',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [HS Sharetime Information Session]',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Challenger Program]',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [CyberSecurity Information Protection Program Participation ]',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Information Session at my high school]',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Campus Visit with my high school]',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Campus Visit (individual)]',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Workforce Development class]',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Corporate Training]',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Teen Arts Festival]',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Summer camp at CCM]',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Hour of Code]',
      
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Middle/High school computing class]',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Middle/High school computing related club]',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Computing-related competitions (e.g., Robotics competition, Lego competition, Cybersecurity, Programming)]',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Afterschool computing-related camp/program]',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Summer computing related camp/program]',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [An AP computing class]',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [A dual enrollment computing class]',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Family or friend influence]',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Family or friend working in the computing field]',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [High school teacher or guidance counselor]',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Employer influence]',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [CCM faculty member]',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [CCM advisor/counselor]',
       'What degree program are you currently enrolled in?',
       'Did you receive information about CCM computing classes from any of the following sources? [High school guidance counselor]',
       'Did you receive information about CCM computing classes from any of the following sources? [High School Teacher]',
       'Did you receive information about CCM computing classes from any of the following sources? [CCM Information Technologies Website]',
       'Did you receive information about CCM computing classes from any of the following sources? [CCM Admissions]',
       'Did you receive information about CCM computing classes from any of the following sources? [CCM advisor/counselor]',
       'Did you receive information about CCM computing classes from any of the following sources? [Employer]',
       'Did you receive information about CCM computing classes from any of the following sources? [CCM Workforce Development]',
       'Did you receive information about CCM computing classes from any of the following sources? [NJ Workforce Development Program]',
       'Did you receive information about CCM computing classes from any of the following sources? [Other]',
       'On a scale of 1 to 5, with 1 being not at all interested and 5 being extremely interested, how interested are you taking more courses in Computer Science, Information Technology or Game Development?',
       'If you answered that you were interested in taking more computing classes, which ones interest you most? [Web Development]',
       'If you answered that you were interested in taking more computing classes, which ones interest you most? [CyberSecurity]',
       'If you answered that you were interested in taking more computing classes, which ones interest you most? [App Development]',
       'If you answered that you were interested in taking more computing classes, which ones interest you most? [Data Analytics]',
       'If you answered that you were interested in taking more computing classes, which ones interest you most? [Machine Learning/Artificial Intelligence]',
       'If you answered that you were interested in taking more computing classes, which ones interest you most? [Computer Programming]',
       'If you answered that you were interested in taking more computing classes, which ones interest you most? [Game Design]',
       'If you answered that you were interested in taking more computing classes, which ones interest you most? [Hardware Installation & Repair]',
        'Race/ethnicity'] , inplace=True)

# %%
#display columns in our new dataframe 
df.columns
# Out:
# Index(['Which course are you currently enrolled in?',
#        'How did you hear about County College of Morris? [CCM Web site]',
#        'How did you hear about County College of Morris? [Social Media]',
#        'How did you hear about County College of Morris? [Community Event]',
#        'How did you hear about County College of Morris? [Family member or friend]',
#        'How did you hear about County College of Morris? [Current CCM student]',
#        'How did you hear about County College of Morris? [CCM Alumni]',
#        'How did you hear about County College of Morris? [High School Teacher]',
#        'How did you hear about County College of Morris? [High School Counselor]',
#        'How did you hear about County College of Morris? [In-app advertisement]',
#        'How did you hear about County College of Morris? [Employer]',
#        'How did you hear about County College of Morris? [Billboard]',
# ...

# %%
#renaming the columns in our new dataset
df.rename(
    columns=({'Which course are you currently enrolled in?': 'course',
       'How did you hear about County College of Morris? [CCM Web site]':'heard_website',
       'How did you hear about County College of Morris? [Social Media]': 'heard_social_media',
       'How did you hear about County College of Morris? [Community Event]': 'heard_community_event',
       'How did you hear about County College of Morris? [Family member or friend]': 'heard_family_member_friend',
       'How did you hear about County College of Morris? [Current CCM student]': 'heard_current_ccm_student',
       'How did you hear about County College of Morris? [CCM Alumni]': 'heard_ccm_alumni',
       'How did you hear about County College of Morris? [High School Teacher]': 'heard_hs_teacher',
       'How did you hear about County College of Morris? [High School Counselor]': 'heard_hs_counselor',
       'How did you hear about County College of Morris? [In-app advertisement]': 'heard_in_app_advertisement',
       'How did you hear about County College of Morris? [Employer]': 'heard_employer',
       'How did you hear about County College of Morris? [Billboard]': 'heard_billboard',
       'How did you hear about County College of Morris? [Television]': 'heard_television',
       'How did you hear about County College of Morris? [Radio]': 'heard_radio',
       'How did you hear about County College of Morris? [Home mailer]':'heard_home_mailer',
       'How did you hear about County College of Morris? [Other]': 'heard_other',
       'To what extent did the following impact your decision to attend County College of Morris? [Affordable cost]': 'impact_affordable_cost',
       'To what extent did the following impact your decision to attend County College of Morris? [Location/convenience]': 'impact_location_convenience',
       'To what extent did the following impact your decision to attend County College of Morris? [Choice of programs]': 'impact_choice_of_programs',
       'To what extent did the following impact your decision to attend County College of Morris? [Online offerings]': 'impact_online_offerings',
       'To what extent did the following impact your decision to attend County College of Morris? [Family/friend referral]': 'impact_family_friends_referral',
       'To what extent did the following impact your decision to attend County College of Morris? [Faculty/staff]': 'impact_faculty_staff',
       'To what extent did the following impact your decision to attend County College of Morris? [College reputation]': 'impact_college_reputation',
       'To what extent did the following impact your decision to attend County College of Morris? [Financial Aid]': 'impact_financial_aid',
       'To what extent did the following impact your decision to attend County College of Morris? [Scholarships]': 'impact_scholarships',
       'To what extent did the following impact your decision to attend County College of Morris? [Small class sizes]': 'impact_small_class_sizes',
       'To what extent did the following impact your decision to attend County College of Morris? [Extra-curricular opportunities]': 'impact_extra_curricular_opportunities',
       'To what extent did the following impact your decision to attend County College of Morris? [Accepted my transfer credits]': 'impact_accepted_my_transfer_credits',
       'To what extent did the following impact your decision to attend County College of Morris? [Negative experience at another college]': 'impact_negative_experience',
       'To what extent did the following impact your decision to attend County College of Morris? [NJ Stars Program]': 'impact_nj_stars_program',
       'To what extent did the following impact your decision to attend County College of Morris? [Ability to transfer CCM credits to a 4-year school]': 'impact_ability_to_transfer_ccm_credits',
       'To what extent did the following impact your decision to attend County College of Morris? [Get college credit while in high school]': 'impact_credits_from_hs',
       'What motivated you to seek a computing class at CCM? [To keep current in computing skills]': 'motivation_to_keep_current_in_computing_skills',
       'What motivated you to seek a computing class at CCM? [Curiosity]': 'motivation_curiosity',
       'What motivated you to seek a computing class at CCM? [Personal Enrichment]': 'motivation_personal_enrichment',
       'What motivated you to seek a computing class at CCM? [Career Advancement]': 'motivation_career_advancement',
       'What motivated you to seek a computing class at CCM? [Career Change]': 'motivation_career_change',
       'What motivated you to seek a computing class at CCM? [Professional Development]': 'motivation_professional_development',
       'What motivated you to seek a computing class at CCM? [Job Displacement]': 'motivation_job_displacement',
       'What motivated you to seek a computing class at CCM? [Financial]': 'motivation_financial',
       'What motivated you to seek a computing class at CCM? [Relocation]': 'motivation_relocation',
       'What motivated you to seek a computing class at CCM? [IT Industry Certifications]': 'motivation_certification',
       'What motivated you to seek a computing class at CCM? [It’s a required class for the degree I’m seeking]': 'motivation_required',
       'Gender': 'gender',
       'Age ': 'age'}),inplace=True
)
#New column names 
df.columns
# Out:
# Index(['course', 'heard_website', 'heard_social_media',
#        'heard_community_event', 'heard_family_member_friend',
#        'heard_current_ccm_student', 'heard_ccm_alumni', 'heard_hs_teacher',
#        'heard_hs_counselor', 'heard_in_app_advertisement', 'heard_employer',
#        'heard_billboard', 'heard_television', 'heard_radio',
#        'heard_home_mailer', 'heard_other', 'impact_affordable_cost',
#        'impact_location_convenience', 'impact_choice_of_programs',
#        'impact_online_offerings', 'impact_family_friends_referral',
#        'impact_faculty_staff', 'impact_college_reputation',
#        'impact_financial_aid', 'impact_scholarships',
#        'impact_small_class_sizes', 'impact_extra_curricular_opportunities',
#        'impact_accepted_my_transfer_credits', 'impact_negative_experience',
#        'impact_nj_stars_program', 'impact_ability_to_transfer_ccm_credits',
#        'impact_credits_from_hs',
#        'motivation_to_keep_current_in_computing_skills',
# ...

# %%
#display info to get null values for each column 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 105 entries, 2023/09/05 9:36:31 PM EST to 2023/09/19 10:44:14 PM EST
# Data columns (total 45 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   course                                          105 non-null    object
#  1   heard_website                                   105 non-null    object
#  2   heard_social_media                              105 non-null    object
#  3   heard_community_event                           105 non-null    object
#  4   heard_family_member_friend                      105 non-null    object
#  5   heard_current_ccm_student                       105 non-null    object
#  6   heard_ccm_alumni                                105 non-null    object
#  7   heard_hs_teacher                                105 non-null    object
# ...

# %%
# fill null values for gender
df['gender']=df['gender'].fillna('Prefer not to say') #fill null values for gender

# %%
# filter out all the columns that starts with impact to fill null values 
impact_columns=df.filter(like='impact').columns
impact_columns
# Out:
# Index(['impact_affordable_cost', 'impact_location_convenience',
#        'impact_choice_of_programs', 'impact_online_offerings',
#        'impact_family_friends_referral', 'impact_faculty_staff',
#        'impact_college_reputation', 'impact_financial_aid',
#        'impact_scholarships', 'impact_small_class_sizes',
#        'impact_extra_curricular_opportunities',
#        'impact_accepted_my_transfer_credits', 'impact_negative_experience',
#        'impact_nj_stars_program', 'impact_ability_to_transfer_ccm_credits',
#        'impact_credits_from_hs'],
#       dtype='object')

# %%
# fill null values with N/A for impact columns
df[impact_columns]=df[impact_columns].fillna('N/A')

# %%
# checked out we don't have any null values in our data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 105 entries, 2023/09/05 9:36:31 PM EST to 2023/09/19 10:44:14 PM EST
# Data columns (total 45 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   course                                          105 non-null    object
#  1   heard_website                                   105 non-null    object
#  2   heard_social_media                              105 non-null    object
#  3   heard_community_event                           105 non-null    object
#  4   heard_family_member_friend                      105 non-null    object
#  5   heard_current_ccm_student                       105 non-null    object
#  6   heard_ccm_alumni                                105 non-null    object
#  7   heard_hs_teacher                                105 non-null    object
# ...

# %% [markdown]
# # Saving New Data as CSV

# %%
#save our data for csv file 
df.to_csv("Cleandatafor2023nonmajorsurvey.csv")

# %% [markdown]
# # Now that our data is cleaned we can start performing analysis

# %% [markdown]
# ### Question 1 Compare the age demographics of the survey over time (2020-2024).  What are the changes over time, if any?

# %%
#read in files for different years
survey20="fall2020non-majors.csv"
#survey21="fall2021non-majors.csv"
survey22="fall2022non-majors.csv"
survey23="fall2023non-majors.csv"
survey24="fall2024non-majors.csv"
# save files to dataframe 
df2020=pd.read_csv(survey20,index_col=0)
#df2021=pd.read_csv(survey21,index_col=0)
df2022=pd.read_csv(survey22,index_col=0)
df2023=pd.read_csv(survey23,index_col=0)
df2024=pd.read_csv(survey24,index_col=0)

# %%
#Save age counts into new data set for each year
df2020 = df2020['Age '].value_counts().reset_index() 
df2022 = df2022['Age '].value_counts().reset_index() 
df2023 = df2023['Age '].value_counts().reset_index()
df2024 = df2024['Age '].value_counts().reset_index() 
#Rename age columns for each year
df2020 = df2020.rename(columns={'Age ': 'age'})
df2022 = df2022.rename(columns={'Age ': 'age'})
df2023 = df2023.rename(columns={'Age ': 'age'})
df2024 = df2024.rename(columns={'Age ': 'age'})
#Create new columns for age counts for each year
df2020.columns = ['age', 'count'] 
df2022.columns = ['age', 'count'] 
df2023.columns = ['age', 'count'] 
df2024.columns = ['age', 'count'] 
#Create new columns for different years
df2020['year'] = 2020
df2022['year'] = 2022
df2023['year'] = 2023
df2024['year'] = 2024

# %%
#Display 2020 data
df2020
# Out:
#               age  count  year
# 0           19-20     94  2020
# 1           21-24     49  2020
# 2  18 and younger     26  2020
# 3           25-34     22  2020
# 4           35-64     10  2020
# 5             65+      1  2020

# %%
#Display 2022 data
df2022
# Out:
#               age  count  year
# 0  18 and younger     44  2022
# 1           19-20     44  2022
# 2           21-24     22  2022
# 3           25-34     16  2022
# 4           35-64      5  2022

# %%
#Display 2023 data
df2023
# Out:
#               age  count  year
# 0           19-20     54  2023
# 1           21-24     21  2023
# 2  18 and younger     12  2023
# 3           25-34     10  2023
# 4           35-64      8  2023

# %%
#new data frame for 2024
df2024
# Out:
#               age  count  year
# 0           19-20     44  2024
# 1           21-24     17  2024
# 2  18 and younger     14  2024
# 3           25-34     11  2024
# 4           35-64      6  2024

# %%
#concatenate data frames together
df_ages=pd.concat([df2020,df2022,df2023,df2024])
#diplay the combined data frames 
df_ages
# Out:
#               age  count  year
# 0           19-20     94  2020
# 1           21-24     49  2020
# 2  18 and younger     26  2020
# 3           25-34     22  2020
# 4           35-64     10  2020
# 5             65+      1  2020
# 0  18 and younger     44  2022
# 1           19-20     44  2022
# 2           21-24     22  2022
# 3           25-34     16  2022
# 4           35-64      5  2022
# 0           19-20     54  2023
# 1           21-24     21  2023
# 2  18 and younger     12  2023
# 3           25-34     10  2023
# 4           35-64      8  2023
# 0           19-20     44  2024
# 1           21-24     17  2024
# 2  18 and younger     14  2024
# 3           25-34     11  2024
# 4           35-64      6  2024

# %% [markdown]
# ### Grouped barchart for age demographics

# %%
#pivot data so that 'age' is the index and each year is a column 
df_pivot = df_ages.pivot_table(index='age', columns='year', values='count', fill_value=0) 
#create grouped bar chart
df_pivot.plot(kind='bar', figsize=(10, 6), width=0.8) 
#titles and labels 
plt.title('Age Demographics From 2020-2024') 
plt.xlabel('Age') 
plt.ylabel('Number of Students') 
#rotate x-axis labels for clarity
plt.xticks(rotation=45, ha='right') 
#place the legend outside the plot area
plt.legend(title='Year', bbox_to_anchor=(1.05, 1), loc='upper left')
#display the graph 
plt.show()

# %% [markdown]
# ## Question #2 What are the top 5 places students heard about CCM?

# %%
#Display column names 
df.columns
# Out:
# Index(['course', 'heard_website', 'heard_social_media',
#        'heard_community_event', 'heard_family_member_friend',
#        'heard_current_ccm_student', 'heard_ccm_alumni', 'heard_hs_teacher',
#        'heard_hs_counselor', 'heard_in_app_advertisement', 'heard_employer',
#        'heard_billboard', 'heard_television', 'heard_radio',
#        'heard_home_mailer', 'heard_other', 'impact_affordable_cost',
#        'impact_location_convenience', 'impact_choice_of_programs',
#        'impact_online_offerings', 'impact_family_friends_referral',
#        'impact_faculty_staff', 'impact_college_reputation',
#        'impact_financial_aid', 'impact_scholarships',
#        'impact_small_class_sizes', 'impact_extra_curricular_opportunities',
#        'impact_accepted_my_transfer_credits', 'impact_negative_experience',
#        'impact_nj_stars_program', 'impact_ability_to_transfer_ccm_credits',
#        'impact_credits_from_hs',
#        'motivation_to_keep_current_in_computing_skills',
# ...

# %%
#Filter out columns beginning with heard
heard_columns=df.filter(like='heard').columns
heard_columns
# Out:
# Index(['heard_website', 'heard_social_media', 'heard_community_event',
#        'heard_family_member_friend', 'heard_current_ccm_student',
#        'heard_ccm_alumni', 'heard_hs_teacher', 'heard_hs_counselor',
#        'heard_in_app_advertisement', 'heard_employer', 'heard_billboard',
#        'heard_television', 'heard_radio', 'heard_home_mailer', 'heard_other'],
#       dtype='object')

# %%
#add up amount of 'yes' responses for each column
heard_yes = df[heard_columns].apply(lambda x: (x=='Yes').sum())
heard_yes
# Out:
# heard_website                 36
# heard_social_media            23
# heard_community_event         18
# heard_family_member_friend    75
# heard_current_ccm_student     47
# heard_ccm_alumni              35
# heard_hs_teacher              45
# heard_hs_counselor            53
# heard_in_app_advertisement    11
# heard_employer                 5
# heard_billboard               14
# heard_television              10
# heard_radio                    5
# heard_home_mailer             20
# heard_other                   16
# dtype: int64

# %%
#Sort in the descending order
heard_sorted = heard_yes.sort_values(ascending=False)
heard_sorted
# Out:
# heard_family_member_friend    75
# heard_hs_counselor            53
# heard_current_ccm_student     47
# heard_hs_teacher              45
# heard_website                 36
# heard_ccm_alumni              35
# heard_social_media            23
# heard_home_mailer             20
# heard_community_event         18
# heard_other                   16
# heard_billboard               14
# heard_in_app_advertisement    11
# heard_television              10
# heard_employer                 5
# heard_radio                    5
# dtype: int64

# %%
#plot the data
plt.figure(figsize=(10, 6))
heard_sorted.plot(kind='barh') 
#labels and title 
plt.title('Most and Least Common Ways People Heard About College')
plt.xlabel('Yes Responses')
plt.ylabel('Ways Students Heard About CCM') 
#display the plot
plt.show()

# %%
#Display top 5 heard responses
heard_top5=heard_sorted.head(5)
heard_top5
# Out:
# heard_family_member_friend    75
# heard_hs_counselor            53
# heard_current_ccm_student     47
# heard_hs_teacher              45
# heard_website                 36
# dtype: int64

# %% [markdown]
# ## Question #3 List top 10 reasons that motivated the students most to seek a computing class at CCM.

# %%
#Filter out columns beginning with motivation
motivation_columns=df.filter(like='motivation').columns
motivation_columns
# Out:
# Index(['motivation_to_keep_current_in_computing_skills',
#        'motivation_curiosity', 'motivation_personal_enrichment',
#        'motivation_career_advancement', 'motivation_career_change',
#        'motivation_professional_development', 'motivation_job_displacement',
#        'motivation_financial', 'motivation_relocation',
#        'motivation_certification', 'motivation_required'],
#       dtype='object')

# %%
#add up amount of 'yes' responses for each column
motivation_yes = df[motivation_columns].apply(lambda x: (x=='Yes').sum())
#display the data
motivation_yes
# Out:
# motivation_to_keep_current_in_computing_skills    55
# motivation_curiosity                              40
# motivation_personal_enrichment                    37
# motivation_career_advancement                     44
# motivation_career_change                          15
# motivation_professional_development               42
# motivation_job_displacement                       12
# motivation_financial                              21
# motivation_relocation                              4
# motivation_certification                           7
# motivation_required                               90
# dtype: int64

# %%
#Sort in the descending order
motivation_sorted = motivation_yes.sort_values(ascending=False)
#data displays sorted values
motivation_sorted
# Out:
# motivation_required                               90
# motivation_to_keep_current_in_computing_skills    55
# motivation_career_advancement                     44
# motivation_professional_development               42
# motivation_curiosity                              40
# motivation_personal_enrichment                    37
# motivation_financial                              21
# motivation_career_change                          15
# motivation_job_displacement                       12
# motivation_certification                           7
# motivation_relocation                              4
# dtype: int64

# %%
#plot the data
plt.figure(figsize=(10, 6))
motivation_sorted.plot(kind='barh') 
#labels and title 
plt.title('Top motivating factors that led student to take computing courses')
plt.xlabel('Yes Responses')
plt.ylabel('Motivation') 
#display the plot
plt.show()

# %%
#Data displaying the top 10 responses
motivation_top10=motivation_sorted.head(10)
motivation_top10
# Out:
# motivation_required                               90
# motivation_to_keep_current_in_computing_skills    55
# motivation_career_advancement                     44
# motivation_professional_development               42
# motivation_curiosity                              40
# motivation_personal_enrichment                    37
# motivation_financial                              21
# motivation_career_change                          15
# motivation_job_displacement                       12
# motivation_certification                           7
# dtype: int64

# %% [markdown]
# ## Question #4 Rank all the student responses that impacted their decision to attend County College of Morris from the most popular to least popular.

# %%
#Filter out columns beginning with impact
impact_columns=df.filter(like='impact').columns
#Display data
impact_columns
# Out:
# Index(['impact_affordable_cost', 'impact_location_convenience',
#        'impact_choice_of_programs', 'impact_online_offerings',
#        'impact_family_friends_referral', 'impact_faculty_staff',
#        'impact_college_reputation', 'impact_financial_aid',
#        'impact_scholarships', 'impact_small_class_sizes',
#        'impact_extra_curricular_opportunities',
#        'impact_accepted_my_transfer_credits', 'impact_negative_experience',
#        'impact_nj_stars_program', 'impact_ability_to_transfer_ccm_credits',
#        'impact_credits_from_hs'],
#       dtype='object')

# %%
# Turn the data frame into series to get value counts
impact_counts = df[impact_columns].apply(pd.Series.value_counts).transpose() #transpose to make column header amount of impact
impact_counts
# Out:
#                                         High Impact  N/A  No Impact  \
# impact_affordable_cost                           64    3          8
# impact_location_convenience                      62    3          9
# impact_choice_of_programs                        47    3         16
# impact_online_offerings                          17    9         40
# impact_family_friends_referral                   31    5         35
# impact_faculty_staff                             17    9         46
# impact_college_reputation                        33    8         29
# impact_financial_aid                             51    5         27
# impact_scholarships                              30    9         47
# impact_small_class_sizes                         32    7         43
# impact_extra_curricular_opportunities            12   10         53
# impact_accepted_my_transfer_credits              18   15         48
# impact_negative_experience                       10   19         61
# ...

# %%
#Reindex the columns from highest to lowest impact 
impact_counts = impact_counts.reindex(['High Impact', 'Some Impact', 'No Impact', 'N/A'], axis=1)
impact_counts
# Out:
#                                         High Impact  Some Impact  No Impact  \
# impact_affordable_cost                           64           30          8
# impact_location_convenience                      62           31          9
# impact_choice_of_programs                        47           39         16
# impact_online_offerings                          17           39         40
# impact_family_friends_referral                   31           34         35
# impact_faculty_staff                             17           33         46
# impact_college_reputation                        33           35         29
# impact_financial_aid                             51           22         27
# impact_scholarships                              30           19         47
# impact_small_class_sizes                         32           23         43
# impact_extra_curricular_opportunities            12           30         53
# ...

# %%
#Create a stacked bar chart
impact_counts.plot(kind='barh', stacked=True)

#title and label the chart
plt.title('Extent the Following things Impacted Students Decision to Attend CCM')
plt.xlabel('Amount of Responses')
plt.ylabel('Impacted Factors')


#place the legend outside the plot area
plt.legend(title='Amount of Impact', bbox_to_anchor=(1.05, 1), loc='upper left')

#display the graph
plt.show()

# %% [markdown]
# ## Sources
# ### Reorder columns
# #### https://docs.kanaries.net/topics/Pandas/pandas-reorder-columns
# ### Transpose columns
# #### https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.transpose.html
# ### stacked bar chart
# #### https://www.shanelynn.ie/bar-plots-in-python-using-pandas-dataframes/
# ### Rotate axis labels
# #### https://stackoverflow.com/questions/10998621/rotate-axis-tick-labels
# ### Move plot legend
# #### https://stackoverflow.com/questions/4700614/how-to-put-the-legend-outside-the-plot
# ### Value counts for a series
# #### https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.value_counts.html#pandas-series-value-counts
# ### Count yes responses with lambda
# #### https://www.geeksforgeeks.org/applying-lambda-functions-to-pandas-dataframe/
# ### Filter out columns with a keyword
# #### https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.filter.html#pandas.DataFrame.filter
